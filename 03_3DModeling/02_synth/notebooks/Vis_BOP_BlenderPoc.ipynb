# %% [markdown]
# ## Script to visualize hdf5 files
#
# https://github.com/DLR-RM/BlenderProc/tree/master/examples/basic
#
# Quick example on using `BlenderProc` to visualize data generated from this example file: `examples/basic/output/0.hdf5`.
#
#
# [](https://github.com/DLR-RM/BlenderProc/blob/master/examples/basic/rendering_0.jpg?raw=true)

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
from blender_proc.vis_results import *

# %%
args = get_BlenderProc_defaults()
args.hdf5_paths = ['/home/redne/pvnet/BlenderProc/examples/bop_object_pose_sampling/output/0.hdf5']
vis_file(args.hdf5_paths[0], args)
# Out:
# /home/redne/pvnet/BlenderProc/examples/bop_object_pose_sampling/output/0.hdf5 contains the following keys: <KeysViewHDF5 ['colors', 'colors_version', 'distance', 'distance_version', 'segcolormap', 'segcolormap_version', 'segmap', 'segmap_version']>
# ...
